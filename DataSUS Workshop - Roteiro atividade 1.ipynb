# %%
# Abra o arquivo baixado no TABNET, apague as linhas indesejadas e salve como uma planilha XLS.

# Roteiro:

# Importar biblioteca Pandas que trabalha com dados
import pandas as pd
import matplotlib.pyplot as plt

# Crie uma variável que contenha o caminho e nome do arquivo excel que deseja importar (de dentro do seu google drive)
arquivo = '/content/drive/MyDrive/A - Diversos/DataSUS - Workshop/tabnet_nascvivo_2020.xlsx'

# Crie o seu DataSet importanto o arquivo
dados = pd.read_excel(arquivo)

# Mostre o resumo do conteúdo de 'dados'
dados

# %%
#  Melhorar os nomes das colunas

dados.rename(columns={'Mês do nascimento': 'MES'}, inplace = True)
dados.rename(columns={'Nascim_p/resid.mãe': 'NASCIMENTO'}, inplace = True)

# mostrar os dados
dados

# %%
# Mostre as informações sobre as colunas de 'dados'
dados.info()

# %%
# Mostre a estatísticas descritivas para as variáveis numéricas 
dados.describe()

# %%
# Mostre um gráfico de barras com o número de gestações

dados.NASCIMENTO.plot.bar()

# %%
meses = dados.MES
nascimentos = dados.NASCIMENTO

# %%
plt.barh(meses, nascimentos)

# %%
plt.barh(meses, nascimentos, color='orange')

# %%
plt.barh(meses, nascimentos, color='orange')

plt.ylabel('Ano de 2020')
plt.xlabel('Nascimentos por mês')
plt.title('Nascidos vivos por mês em 2020 - DataSUS TabNet')
