# %%
# Abra o arquivo baixado no OpenDataSUS em CSV

# Roteiro:

# Importar biblioteca Pandas que trabalha com dados
import pandas as pd
import matplotlib.pyplot as plt

# Crie uma variável que contenha o caminho e nome do arquivo excel que deseja importar (de dentro do seu google drive)
arquivo = '/content/drive/MyDrive/A - Diversos/DataSUS - Workshop/SINASC_2020.csv'

# Crie o seu DataSet importanto o arquivo
dados = pd.read_csv(arquivo, sep=';')

# Mostre o resumo do conteúdo de 'dados'
dados
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  ESCMAE  \
# 0             1  6205224.0      110020        1      34.0        2.0     5.0
# 1             1        NaN      110020        4      18.0        1.0     9.0
# 2             1  3970442.0      110020        1      26.0        2.0     5.0
# 3             1  5701929.0      120001        1      29.0        5.0     4.0
# 4             1  5701929.0      120001        1      20.0        5.0     4.0
# ...         ...        ...         ...      ...       ...        ...     ...
# 2730140       1    10529.0      530010        1      21.0        5.0     3.0
# 2730141       1    10499.0      530010        1      28.0        1.0     5.0
# ...

# %%
# Mostre as informações sobre as colunas de 'dados'
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730145 entries, 0 to 2730144
# Data columns (total 61 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ORIGEM      int64
#  1   CODESTAB    float64
#  2   CODMUNNASC  int64
#  3   LOCNASC     int64
#  4   IDADEMAE    float64
#  5   ESTCIVMAE   float64
#  6   ESCMAE      float64
#  7   CODOCUPMAE  float64
#  8   QTDFILVIVO  float64
#  9   QTDFILMORT  float64
#  10  CODMUNRES   int64
#  11  GESTACAO    float64
#  12  GRAVIDEZ    float64
#  13  PARTO       float64
#  14  CONSULTAS   float64
#  15  DTNASC      int64
#  16  HORANASC    float64
#  17  SEXO        int64
#  18  APGAR1      float64
#  19  APGAR5      float64
#  20  RACACOR     float64
#  21  PESO        float64
#  22  IDANOMAL    float64
#  23  DTCADASTRO  int64
#  24  CODANOMAL   object
#  25  NUMEROLOTE  float64
#  26  VERSAOSIST  object
#  27  DTRECEBIM   float64
#  28  DIFDATA     int64
#  29  DTRECORIGA  float64
#  30  NATURALMAE  float64
# ...

# %%
# Mostre um gráfico de barras com o número de gestações
robson = dados.TPROBSON.value_counts(ascending=True);
robson.plot.bar()

# %%
# mostrar o histograma da Idade
dados.PESO.plot.hist(bins=30)

# %%
# mostrar o mesmo gráfico utilizando a biblioteca SEABORN e o MATPLOTLIB 
# assim teremos mais flexibilidade para editar o gráfico
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# mostrar a distribuição da idade
sns.displot(dados.PESO, color='indianred')

# %%
ax = sns.violinplot(data=dados, x='SEXO', y='SEMAGESTAC', inner=None, color=".8")
